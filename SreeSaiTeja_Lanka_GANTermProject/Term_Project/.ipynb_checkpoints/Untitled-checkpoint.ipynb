# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

#Useful function
def createFileList(myDir, format='.png'):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)

# load the original image
    for file in fileList:
        print(file)
        img_file = Image.open(file)
    # img_file.show()

    # get original image parameters...
        width, height = img_file.size
        format = img_file.format
        mode = img_file.mode

    # Make image Greyscale
        img_grey = img_file.convert('L')
    #img_grey.save('result.png')
    #img_grey.show()

    # Save Greyscale values
        value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
        value = value.flatten()
        print(value)
        with open(r"C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\img1_pixels.csv", "a") as f:
            writer = csv.writer(f)
            writer.writerow(value)
            
myFileList = createFileList(r"C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM")
# Out:
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_1.png
# [161  73 188 ...  65 121 161]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_10.png
# [ 50  22 204 ... 240 244 145]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_100.png
# [ 34  18  34 ... 240 232 177]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_1000.png
# [ 85 161  85 ...  54  38 133]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_101.png
# [ 97 228 224 ... 161  85  18]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_102.png
# [ 85  73 244 ...  38 184 180]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_103.png
# [ 54  42  30 ... 145  69 161]
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\CM_104.png
# [220  18 109 ...  74  26  30]
# ...

# %%
import os
import gc
import pickle
import numpy as np
from pathlib import Path
#force to a gpu
#os.environ['CUDA_VISIBLE_DEVICES'] = '1'
print(os.listdir(r"C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM"))
# Out:
# ['CM_1.png', 'CM_10.png', 'CM_100.png', 'CM_1000.png', 'CM_101.png', 'CM_102.png', 'CM_103.png', 'CM_104.png', 'CM_105.png', 'CM_106.png', 'CM_107.png', 'CM_108.png', 'CM_109.png', 'CM_11.png', 'CM_110.png', 'CM_111.png', 'CM_112.png', 'CM_113.png', 'CM_114.png', 'CM_115.png', 'CM_116.png', 'CM_117.png', 'CM_118.png', 'CM_119.png', 'CM_12.png', 'CM_120.png', 'CM_121.png', 'CM_122.png', 'CM_123.png', 'CM_124.png', 'CM_125.png', 'CM_126.png', 'CM_127.png', 'CM_128.png', 'CM_129.png', 'CM_13.png', 'CM_130.png', 'CM_131.png', 'CM_132.png', 'CM_133.png', 'CM_134.png', 'CM_135.png', 'CM_136.png', 'CM_137.png', 'CM_138.png', 'CM_139.png', 'CM_14.png', 'CM_140.png', 'CM_141.png', 'CM_142.png', 'CM_143.png', 'CM_144.png', 'CM_145.png', 'CM_146.png', 'CM_147.png', 'CM_148.png', 'CM_149.png', 'CM_15.png', 'CM_150.png', 'CM_151.png', 'CM_152.png', 'CM_153.png', 'CM_154.png', 'CM_155.png', 'CM_156.png', 'CM_157.png', 'CM_158.png', 'CM_159.png', 'CM_16.png', 'CM_160.png', 'CM_161.png', 'CM_162.png
# ...

# %%
#config
INPUT_SHAPE = (256,256,1)

input_path = Path((r'C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old'))
train_dir =  input_path/"train"
test_dir = input_path/ "test"
print(train_dir)

train_csv = r"C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\img1_pixels.csv"
print(train_csv)
submission_file = input_path/"sample_submission.csv"
# Out:
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train
# C:\Users\lanka\Desktop\CSE583_PRML\Term_Project\wallpaper_old\train\CM\img1_pixels.csv

# %%
# Read the dataset description
from pandas import read_csv


tagged = dict([(p,w) for _,p,w in read_csv( str(train_csv)).to_records()])
submit = [p for _,p,_ in read_csv(str(submission_file)).to_records()]
join   = list(tagged.keys()) + submit
len(tagged),len(submit),len(join),list(tagged.items())[:5],submit[:5]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-6e291fedf04c> in <module>
#       3
#       4
# ----> 5 tagged = dict([(p,w) for _,p,w in read_csv( str(train_csv)).to_records()])
#       6 submit = [p for _,p,_ in read_csv(str(submission_file)).to_records()]
#       7 join   = list(tagged.keys()) + submit
#
# ...

# %%
# Determise the size of each image
from os.path import isfile
from PIL import Image as pil_image
from tqdm import tqdm

def expand_path(p):
    if isfile(str(train_dir / p)): return str(train_dir / p)
    if isfile(str(test_dir / p)): return str(test_dir / p)
    return p

p2size = {}
for p in tqdm(join):
    size      = pil_image.open(expand_path(p)).size
    p2size[p] = size
len(p2size), list(p2size.items())[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-4a827f23ab06> in <module>
#      10
#      11 p2size = {}
# ---> 12 for p in tqdm(join):
#      13     size      = pil_image.open(expand_path(p)).size
#      14     p2size[p] = size
#
# NameError: name 'join' is not defined
